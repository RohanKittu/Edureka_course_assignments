# %% [markdown]
# # Problem statements

# %% [markdown]
# ## Case Study
# - Write a program which will find factors of given number and find whether the
# factor is even or odd.
# Hint: Use Loop with if-else statements
# - Write a code which accepts a sequence of words as input and prints the words in a
# sequence after sorting them alphabetically.
# Hint: In case of input data being supplied to the question, it should be assumed to
# be a console input.
# - Write a program, which will find all the numbers between 1000 and 3000 (both
# included) such that each digit of a number is an even number. The numbers
# obtained should be printed in a comma separated sequence on a single line.
# Hint: In case of input data being supplied to the question, it should be assumed to
# be a console input. Divide each digit with 2 and verify is it even or not.
# - Write a program that accepts a sentence and calculate the number of letters and
# digits.
# Suppose if the entered string is: Python0325
# Then the output will be:
# LETTERS: 6
# DIGITS:4
# Hint: Use built-in functions of string.
# - Design a code which will find the given number is Palindrome number or not.
# Hint: Use built-in functions of string

# %% [markdown]
# ##### Write a program which will find factors of given number and find whether the factor is even or odd. Hint: Use Loop with if-else statements

# %%
def factor():
    number=int(input("\nEnter the number for which you want to find the factor :- "))
    for i in range(1,number+1):
        if(number%i==0):
            if(i%2==0):
                print("The number is %d and its an even number"%(i))
            else:
                print("The number is %d and its an odd number"%(i))
        else:
            pass
factor()
# Out:
# Enter the number for which you want to find the factor :- 4
# The number is 1 and its odd number
# The number is 2 and its even number
# The number is 4 and its even number

# %% [markdown]
# ##### Write a code which accepts a sequence of words as input and prints the words in a sequence after sorting them alphabetically. Hint: In case of input data being supplied to the question, it should be assumed to be a console input.

# %%
#string=input('\nEnter the sequence of words :- ')
string=input('\nEnter the sequence of words :- ')
def sortedSentence(Sentence): 
      
    # Spliting the Sentence into words 
    words = Sentence.split(" ") 
      
    # Sorting the words 
    words.sort() 
      
    # Making new Sentence by  
    # joining the sorted words 
    newSentence = " ".join(words) 
      
    # Return newSentence 
    return newSentence 
  
#Main function
print(sortedSentence(string)) 
  
# Print the sortedSentence 
#print(sortedSentence(Sentence))
# Out:
# Enter the sequence of words :- rohan hello word ,its great
# ,its great hello rohan word

# %% [markdown]
# ##### Write a program, which will find all the numbers between 1000 and 3000 (both included) such that each digit of a number is an even number. The numbers obtained should be printed in a comma separated sequence on a single line. Hint: In case of input data being supplied to the question, it should be assumed to be a console input. Divide each digit with 2 and verify is it even or not.

# %%
for i in list(range(1000,3001)):
    for j in range(0,len(list(str(i)))):
        if(int(list(str(i))[j])%2==0):
            print("The number is %d digit value is :- %d and its even digit"%(i,j+1))
        else:
            print("The number is %d digit value is :- %d and its an odd digit"%(i,j+1))
# Out:
# The number is 1000 digit value is :- 1 and its an odd digit
# The number is 1000 digit value is :- 2 and its even digit
# The number is 1000 digit value is :- 3 and its even digit
# The number is 1000 digit value is :- 4 and its even digit
# The number is 1001 digit value is :- 1 and its an odd digit
# The number is 1001 digit value is :- 2 and its even digit
# The number is 1001 digit value is :- 3 and its even digit
# The number is 1001 digit value is :- 4 and its an odd digit
# The number is 1002 digit value is :- 1 and its an odd digit
# The number is 1002 digit value is :- 2 and its even digit
# The number is 1002 digit value is :- 3 and its even digit
# The number is 1002 digit value is :- 4 and its even digit
# The number is 1003 digit value is :- 1 and its an odd digit
# The number is 1003 digit value is :- 2 and its even digit
# The number is 1003 digit value is :- 3 and its even digit
# The number is 1003 digit value is :- 4 and its an odd digit
# ...

# %% [markdown]
# ##### Write a program that accepts a sentence and calculate the number of letters and digits. Suppose if the entered string is: Python0325 Then the output will be: LETTERS: 6 DIGITS:4 Hint: Use built-in functions of string.

# %%
#Function for counting the letters and digits
def count_sentence_and_digits(data):
    #init the counter values
    count_letter=0
    count_digits=0
    #For loop for calculating letters and digits
    for i in range(0,len(list(data))):
        if(list(data)[i].isdigit()==True):
            count_digits+=1
        else:
            count_letter+=1
    #Returning the count of both letters and digits
    return((count_letter,count_digits))

#Main program
#Taking the input from the user and passing to the above function
value_count=count_sentence_and_digits(input("\nEnter the value :- "))
#Printing the both the values
print("The number of digits :- ",value_count[0],"\nThe number of letters :- ",value_count[1])
# Out:
# Enter the value :- hello12
# The number of digits :-  5
# The number of letters :-  2

# %% [markdown]
# ##### Design a code which will find the given number is Palindrome number or not. Hint: Use built-in functions of string

# %%
def palindrome_check(number):
    if(type(number)==int):
        if(str(number)==str(number)[::-1]):
            print("The given  number %d is a palindrome"%(number))
        else:
            print("The given number %d is not a palindrom"%(number))
    elif(type(number)==str):
        if(number==number[::-1]):
            print("The given  string %s is a palindrome"%(number))
        else:
            print("The given string %s is not a palindrom"%(number))
                
palindrome_check("mohom")
# Out:
# The given  string mohom is a palindrome
